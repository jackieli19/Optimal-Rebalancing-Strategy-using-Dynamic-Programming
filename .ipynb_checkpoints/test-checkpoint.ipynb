# %%
# Implementation of:
#   Title: Optimal Rebalancing Strategy Using Dynamic Programming for Institutional Portfolios / MIT Working Paper
#   Authors: Walter Sun, Ayres Fan, Li-Wei Che, Tom Schouwenaars, Marius A. Albota

# INSTRUCTIONS: Keep the Data.csv file in the same directory and do NOT change the column names. Uncheck '#' to see the graphs if required. 

# Import Required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
from operator import itemgetter
import time

# Project Information
print( '############################################################################################')
print( 'Project: Optimal Rebalancing Strategy Using Dynamic Programming for Institutional Portfolios')
print( '############################################################################################')
print( ' ')
# Out:
# ############################################################################################
# Project: Optimal Rebalancing Strategy Using Dynamic Programming for Institutional Portfolios
# ############################################################################################

# %%
# Start Timer to measure Total Run Time of Script
t0 = time.clock()

####################################################################################################################
# CALCULATE OPTIMAL PORTFOLIO WEIGHT - EFFICIENT FRONTIER MEAN-VARIANCE OPTIMIZATION

#Load csv with Websites on the dataframe
Data = pd.read_csv('Data.csv')

# Calculate Daily Returns for Assets A & B using Vectoring
Data['Returns_A'] = Data['Close_A']/Data['Close_A'].shift(1)-1
Data['Returns_B'] = Data['Close_B']/Data['Close_B'].shift(1)-1
# Replace NANs with zeros in first line (since there are no returns in the first period)
Data['Returns_A'].fillna(0, inplace=True)
Data['Returns_B'].fillna(0, inplace=True)

#Calculate Covariance Matrix
Covariance_Matrix = np.cov(Data['Returns_A'],Data['Returns_B'])

# Allocate Initial weight factor and precision
wA=0.0
# Define detail of weight increments
detail = 0.0005
# Define Amount Invested in Period 0
initial_amount_invested = 1000000000
# Define Trading Costs of Asset A (in basis points)
CA = 60
# Define Trading Costs of Asset B (in basis points)
CB = 40

# Create DataFrame
index = np.arange(1 / detail) 
columns = ['WeightA','Variance']
A = pd.DataFrame(columns=columns, index = index)

# %%
# Create for loop to calculate the Efficient Frontier Utility and identify its minimum along with respective weight where this occurs
for i in range(0,int(1 / detail)):
    A['WeightA'][i] = wA
    A['Variance'][i] = wA * (wA * Covariance_Matrix[0,0] + \
                (1 - wA) * Covariance_Matrix[0,1]) + (1 - wA) * (wA * Covariance_Matrix[1,0] + (1 - wA) * Covariance_Matrix[1,1])
    
    # Calculate minimum Efficient Frontier Function value along with respective weight
    try:
        # Check if next point Variance is lower than previous one (if it is keep the weight at which this occurs)
        if A['Variance'][i] < A['Variance'][i-1]:
            Optimal_WeightA = A['WeightA'][i]
    except:
        pass
        
    # Increase weight by increment previously specified            
    wA = wA + detail  

# Print the calculated Optimal Portfolio Weight    
print('Optimal Portfolio Weight According to Efficient Frontier Using Mean-Variance Optimization: ' +\
str(Optimal_WeightA))

# Plot Efficient Frontier using Mean Variance Optimization
#plt.plot(A['WeightA'] ,A['Variance'])
#plt.title('Efficient Frontier using Mean-Variance Optimization')
#plt.xlabel('Weight of Asset A (Developed Market Index)')
#plt.ylabel('Variance')
#plt.show()
# Out:
# Optimal Portfolio Weight According to Efficient Frontier Using Mean-Variance Optimization: 0.6144999999999877

# %%
####################################################################################################################
# NO REBALANCING - Calculate Investment Parameters of Portfolio if Optimal Weight is selected in period 0 and then weights are left to drift according to market prices

# Copy the DataFrame with the read data
CData = Data

# Define Additional Columns in the DataFrame
CData['WeightA'] = CData['InvestmentA'] = CData['InvestmentB'] = CData['Total_Returns'] = CData['Variance'] = CData['Expected_Utility_Current'] = CData['Variance_Optimal'] = CData['Expected_Utility_Optimal'] = CData['TC'] = CData['CEC'] =  0.0

# Define Period 0 parameters
CData['WeightA'][0] = Optimal_WeightA
CData['InvestmentA'][0] = CData['WeightA'][0]*initial_amount_invested
CData['InvestmentB'][0] = (1-Optimal_WeightA)*initial_amount_invested

# Calculate Portfolio Parameters in the Subsequent Time Periods
for i in range(1,len(Data)):
    # Calculate Value of Investments in Asset A & B
    CData['InvestmentA'][i] = CData['InvestmentA'][i-1]*(CData['Returns_A'][i]+1)
    CData['InvestmentB'][i] = CData['InvestmentB'][i-1]*(CData['Returns_B'][i]+1)
    # Calculate the New Weight of Asset A (this changes because of the change in price of the assets over time)
    CData['WeightA'][i] = CData['InvestmentA'][i] / (CData['InvestmentA'][i]+CData['InvestmentB'][i])
    # Calculate the Total Return of the Portfolio in the period
    CData['Total_Returns'][i] = (CData['InvestmentA'][i]+CData['InvestmentB'][i])/(CData['InvestmentA'][i-1]+CData['InvestmentB'][i-1])-1
    # Calculate the Expected Utility
    CData['Expected_Utility_Current'][i] = math.log10(1+np.mean(CData['Total_Returns'][0:i]))- \
                                            CData['Variance'][i]/(2*((1+np.mean(CData['Total_Returns'][0:i]))**2))
    
    #Calculate the Variance of the Portfolio if the weight was Optimal (i.e. calculated using Mean Variance before)
    CData['Variance_Optimal'][i] = ((CData['Returns_A'][i]-CData['Total_Returns'][i])**2)*(Optimal_WeightA**2) + \
                                                ((CData['Returns_B'][i]-CData['Total_Returns'][i])**2)*((1-Optimal_WeightA)**2) + \
                                                2*(1-Optimal_WeightA)*CData['WeightA'][i]*Covariance_Matrix[1,0]            
    # Calculate Optimal Expected Utility (i.e. Utility if the weight was Optimal)
    CData['Expected_Utility_Optimal'][i] = math.log10(1+np.mean(CData['Total_Returns'][0:i]))- \
                                                CData['Variance_Optimal'][i]/(2*((1+np.mean(CData['Total_Returns'][0:i]))**2))
            
    # Calculate Certainty Equivalent Costs (i.e. cost of not being at the optimal utility)      
    CData['CEC'][i] = (math.exp(CData['Expected_Utility_Optimal'][i]) - math.exp(CData['Expected_Utility_Current'][i]))*10*initial_amount_invested

# Print the cost of not rebalancing the portfolio to the Optimal Weight and letting it drift according to market prices
print ('Cost of not rebalancing to Optimal Portfolio Weight: ' + str(np.abs(np.sum(CData['CEC']))))
print (' ')

# Plot WeightA Change over time
#CData['WeightA'].plot()
#plt.title('No Rebalancing')
#plt.xlabel('Days')
#plt.ylabel('Weight of Asset A (Developed Market Index)')
#plt.show()

####################################################################################################################
# DYNAMIC PROGRAMMIN REBALANCING

# Determine Additional Parameters in the DataFrame
Data['Min_Cost_Weight'] = Data['TC'] = Data['CEC'] = Data['Total_Costs'] = Data['Low_Bound'] = Data['High_Bound'] = Data['Rebalance'] = 0.0

# Declare new DataFrame which will contain the time series
index = np.arange(1 / detail + 1) 
columns = ['Close_A', 'Close_B','Returns_A', 'Returns_B', 'WeightA', 'Investment_A', 'Investment_B', 'Total_Returns', 'Variance_Current', 'Expected_Utility_Current', 'Variance_Optimal', 'Expected_Utility_Optimal','CEC', 'TC','Costs']
Cost_Min = pd.DataFrame(columns=columns, index = index)

# Cost_Min DataFrame contains all the possible weights of the portfolio (3 decimal accuracy) for every period. The weight minimising costs (TC+CEC) is imported
# to the main dataframe where Total Costs are then calculated 

# Define Period 0 Parameters
Data['Min_Cost_Weight'][0] = Optimal_WeightA

for line1 in range(1,len(Data)):
    # Define Initial parameters of the Cost_Min DataFrame
    Cost_Min['Costs'][0] = Cost_Min['WeightA'][0] = Cost_Min['Investment_A'][0] = 0
    Cost_Min['Close_A'] = Data['Close_A'][line1]
    Cost_Min['Close_B'] = Data['Close_B'][line1]
    Cost_Min['Returns_A'] = Data['Returns_A'][line1]
    Cost_Min['Returns_B'] = Data['Returns_B'][line1]
    Cost_Min['Investment_B'][0] = initial_amount_invested
    Cost_Min['Total_Returns'] = CData['Total_Returns'][line1]
    
    # Calculate the Investments, Expected Utility, Optimal_Expected_Utility and Costs for every possible weight
    for line2 in range(1,len(Cost_Min)-1):
        # Define weight in the current period (this is equal to the weight in the previous period plus 0.0005)
        Cost_Min['WeightA'][line2] = Cost_Min['WeightA'][line2-1] + detail
        # Calculate the Value of the two Investments
        Cost_Min['Investment_A'][line2] = Cost_Min['WeightA'][line2] * initial_amount_invested
        Cost_Min['Investment_B'][line2] = (1-Cost_Min['WeightA'][line2]) * initial_amount_invested
        # Calculate the Variance with the Current Portfolio
        Cost_Min['Variance_Current'][line2] = ((Cost_Min['Returns_A'][line2]-Cost_Min['Total_Returns'][line2])**2)* \
                                                (Cost_Min['WeightA'][line2]**2) + ((Cost_Min['Returns_B'][line2]-Cost_Min['Total_Returns'][line2])**2)* \
                                                ((1-Cost_Min['WeightA'][line2])**2) + 2*(1-Cost_Min['WeightA'][line2])*Cost_Min['WeightA'][line2]*Covariance_Matrix[1,0]
        # Calculate the Expected Utility with the Current Portfolio Weight
        Cost_Min['Expected_Utility_Current'][line2] = math.log10(1+np.mean(CData['Total_Returns'][0:line1]))- \
                                                Cost_Min['Variance_Current'][line2]/(2*((1+np.mean(CData['Total_Returns'][0:line1]))**2))
            
        # Calculate the Variance if the Optimal Portfolio Weight was Selected   
        Cost_Min['Variance_Optimal'][line2] = ((Cost_Min['Returns_A'][line2]-Cost_Min['Total_Returns'][line2])**2)*(Optimal_WeightA**2) + \
                                                ((Cost_Min['Returns_B'][line2]-Cost_Min['Total_Returns'][line2])**2)*((1-Optimal_WeightA)**2) + \
                                                2*(1-Optimal_WeightA)*Cost_Min['WeightA'][line2]*Covariance_Matrix[1,0]            
        # Calculate the Expected Utility if the Optimal Portfolio Weight was Selected
        Cost_Min['Expected_Utility_Optimal'][line2] = math.log10(1+np.mean(CData['Total_Returns'][0:line1]))- \
                                                Cost_Min['Variance_Optimal'][line2]/(2*((1+np.mean(CData['Total_Returns'][0:line1]))**2))
            
        # Calculate the Certenty Equivalent Costs in the particular period (i.e. cost of not rebalancing to Optimal Portfolio)    
        Cost_Min['CEC'][line2] = (math.exp(Cost_Min['Expected_Utility_Optimal'][line2]) - math.exp(Cost_Min['Expected_Utility_Current'][line2]))*initial_amount_invested
    
        # Calculate the Transaction Costs to be incurred if rebalancing is to take place
        Cost_Min['TC'][line2] =  (CA*math.fabs(Optimal_WeightA-(Cost_Min['WeightA'][line2])) + CB*math.fabs((1-Optimal_WeightA)-(1-(Cost_Min['WeightA'][line2]))))
        
        # Calculate Total Costs to be incurred if rebalancing is to take place
        Cost_Min['Costs'][line2] = Cost_Min['CEC'][line2] + Cost_Min['TC'][line2]
    
    
    #plt.plot(Cost_Min['WeightA'],Cost_Min['CEC'])
    #plt.plot(Cost_Min['WeightA'],Cost_Min['TC'])
    #plt.title('Rebalancing Selection Band')
    #plt.xlabel('Portfolio Weight of Asset A (Developed Market Index)')
    #plt.ylabel('Basis Points')
    #plt.legend(['CEC','TC'])
    #plt.show()
    
    # Caclulate the low and high threshold above and below which total costs of rebalancing are negative (i.e. profit from rebalancing) 
    for line2 in range(min(enumerate(Cost_Min['Costs']), key=itemgetter(1))[0],len(Cost_Min)-1):
        if Cost_Min['Costs'][line2] < 0:
                Data['High_Bound'][line1] = Cost_Min['WeightA'][line2]
        else:
            break
    for line2 in range(1,len(Cost_Min)-1):
        if Cost_Min['Costs'][line2] > 0:
                Data['Low_Bound'][line1] = Cost_Min['WeightA'][line2]
        else:
            break
    
    # Populate main timeseries DataFrame with Weight, TC and CEC that minimise total costs of rebalancing                
    Data['Min_Cost_Weight'][line1] = Cost_Min['WeightA'][min(enumerate(Cost_Min['Costs'][1:len(Cost_Min)]), key=itemgetter(1))[0]]
    Data['TC'][line1] = Cost_Min['TC'][min(enumerate(Cost_Min['Costs'][1:len(Cost_Min)]), key=itemgetter(1))[0]]
    Data['CEC'][line1] = Cost_Min['CEC'][min(enumerate(Cost_Min['Costs'][1:len(Cost_Min)]), key=itemgetter(1))[0]]
    
    # Print a string showing where in time we currently are (how many datapoints have been calculated)   
    print ('Finished with ' + str(line1) + ' out of ' + str(len(Data)-1) + ' Datapoints')

    
Data['New_WeightA'] = Data['WeightA']

# Account for Future Costs in Rebalancing Decision        
Data['Total_Costs'][len(Data)-1] = Data['TC'][len(Data)-1] + Data['CEC'][len(Data)-1]
for line1 in range(len(Data)-2,1,-1):
    Data['Total_Costs'][line1] = Data['TC'][line1] + Data['CEC'][line1] + Data['Total_Costs'][line1-1]

# If the Current Weight is Below the Lower Threshold / Above the Higher Threshold, Rebalance taking into account the Costs of the Next Period    
for line1 in range(1,len(Data)):
    if Data['New_WeightA'][line1] > Data['Low_Bound'][line1] and Data['New_WeightA'][line1] < Data['High_Bound'][line1]:
        Data['Rebalance'][line1] = 0   
    else:
        Data['Rebalance'][line1] = 1
        Data['New_WeightA'][line1+1] = Data['Min_Cost_Weight'][line1]
        Data['InvestmentA'][line1+1] = Data['New_WeightA'][line1+1]*(Data['InvestmentA'][line1]+Data['InvestmentB'][line1])
        Data['InvestmentB'][line1+1] = (1-Data['New_WeightA'][line1+1])*(Data['InvestmentA'][line1]+Data['InvestmentB'][line1])

        for line in range(line1+2,len(Data)):
            Data['InvestmentA'][line] = Data['InvestmentA'][line-1]*(Data['Returns_A'][line]+1)
            Data['InvestmentB'][line] = Data['InvestmentB'][line-1]*(Data['Returns_B'][line]+1)
            Data['New_WeightA'][line] = Data['InvestmentA'][line] / (Data['InvestmentA'][line]+Data['InvestmentB'][line])
# Out:
# Cost of not rebalancing to Optimal Portfolio Weight: 33242104.29163865
#
# Finished with 1 out of 325 Datapoints
# Finished with 2 out of 325 Datapoints
# Finished with 3 out of 325 Datapoints
# Finished with 4 out of 325 Datapoints
# Finished with 5 out of 325 Datapoints
# Finished with 6 out of 325 Datapoints
# Finished with 7 out of 325 Datapoints
# Finished with 8 out of 325 Datapoints
# Finished with 9 out of 325 Datapoints
# Finished with 10 out of 325 Datapoints
# Finished with 11 out of 325 Datapoints
# Finished with 12 out of 325 Datapoints
# Finished with 13 out of 325 Datapoints
# Finished with 14 out of 325 Datapoints
# Finished with 15 out of 325 Datapoints
# Finished with 16 out of 325 Datapoints
# Finished with 17 out of 325 Datapoints
# Finished with 18 out of 325 Datapoints
# Finished with 19 out of 325 Datapoints
# Finished with 20 out of 325 Datapoints
# Finished with 21 out of 325 Datapoints
# Finished with 22 out of 325 Datapoints
# Finished with 23 out of 325 Datapoints
# Finished with 24 out of 325 Datapoints
# Finished with 25 out of 325 Datapoints
# Finished with 26 out of 325 Datapoints
# Finished with 27 out of 325 Datapoints
# Finished with 28 out of 325 Datapoints
# Finished with 29 out of 325 Datapoints
# Finished with 30 out of 325 Datapoints
# Finished with 31 out of 325 Datapoints
# Finished with 32 out of 325 Datapoints
# Finished with 33 out of 325 Datapoints
# Finished with 34 out of 325 Datapoints
# Finished with 35 out of 325 Datapoints
# Finished with 36 out of 325 Datapoints
# Finished with 37 out of 325 Datapoints
# Finished with 38 out of 325 Datapoints
# Finished with 39 out of 325 Datapoints
# Finished with 40 out of 325 Datapoints
# Finished with 41 out of 325 Datapoints
# Finished with 42 out of 325 Datapoints
# Finished with 43 out of 325 Datapoints
# Finished with 44 out of 325 Datapoints
# Finished with 45 out of 325 Datapoints
# Finished with 46 out of 325 Datapoints
# Finished with 47 out of 325 Datapoints
# Finished with 48 out of 325 Datapoints
# Finished with 49 out of 325 Datapoints
# Finished with 50 out of 325 Datapoints
# Finished with 51 out of 325 Datapoints
# Finished with 52 out of 325 Datapoints
# Finished with 53 out of 325 Datapoints
# Finished with 54 out of 325 Datapoints
# Finished with 55 out of 325 Datapoints
# Finished with 56 out of 325 Datapoints
# Finished with 57 out of 325 Datapoints
# Finished with 58 out of 325 Datapoints
# Finished with 59 out of 325 Datapoints
# Finished with 60 out of 325 Datapoints
# Finished with 61 out of 325 Datapoints
# Finished with 62 out of 325 Datapoints
# Finished with 63 out of 325 Datapoints
# Finished with 64 out of 325 Datapoints
# Finished with 65 out of 325 Datapoints
# Finished with 66 out of 325 Datapoints
# Finished with 67 out of 325 Datapoints
# Finished with 68 out of 325 Datapoints
# Finished with 69 out of 325 Datapoints
# Finished with 70 out of 325 Datapoints
# Finished with 71 out of 325 Datapoints
# Finished with 72 out of 325 Datapoints
# Finished with 73 out of 325 Datapoints
# Finished with 74 out of 325 Datapoints
# Finished with 75 out of 325 Datapoints
# Finished with 76 out of 325 Datapoints
# Finished with 77 out of 325 Datapoints
# Finished with 78 out of 325 Datapoints
# Finished with 79 out of 325 Datapoints
# Finished with 80 out of 325 Datapoints
# Finished with 81 out of 325 Datapoints
# Finished with 82 out of 325 Datapoints
# Finished with 83 out of 325 Datapoints
# Finished with 84 out of 325 Datapoints
# Finished with 85 out of 325 Datapoints
# Finished with 86 out of 325 Datapoints
# Finished with 87 out of 325 Datapoints
# Finished with 88 out of 325 Datapoints
# Finished with 89 out of 325 Datapoints
# Finished with 90 out of 325 Datapoints
# Finished with 91 out of 325 Datapoints
# Finished with 92 out of 325 Datapoints
# Finished with 93 out of 325 Datapoints
# Finished with 94 out of 325 Datapoints
# Finished with 95 out of 325 Datapoints
# Finished with 96 out of 325 Datapoints
# Finished with 97 out of 325 Datapoints
# Finished with 98 out of 325 Datapoints
# Finished with 99 out of 325 Datapoints
# Finished with 100 out of 325 Datapoints
# Finished with 101 out of 325 Datapoints
# Finished with 102 out of 325 Datapoints
# Finished with 103 out of 325 Datapoints
# Finished with 104 out of 325 Datapoints
# Finished with 105 out of 325 Datapoints
# Finished with 106 out of 325 Datapoints
# Finished with 107 out of 325 Datapoints
# Finished with 108 out of 325 Datapoints
# Finished with 109 out of 325 Datapoints
# Finished with 110 out of 325 Datapoints
# Finished with 111 out of 325 Datapoints
# Finished with 112 out of 325 Datapoints
# Finished with 113 out of 325 Datapoints
# Finished with 114 out of 325 Datapoints
# Finished with 115 out of 325 Datapoints
# Finished with 116 out of 325 Datapoints
# Finished with 117 out of 325 Datapoints
# Finished with 118 out of 325 Datapoints
# Finished with 119 out of 325 Datapoints
# Finished with 120 out of 325 Datapoints
# Finished with 121 out of 325 Datapoints
# Finished with 122 out of 325 Datapoints
# Finished with 123 out of 325 Datapoints
# Finished with 124 out of 325 Datapoints
# Finished with 125 out of 325 Datapoints
# Finished with 126 out of 325 Datapoints
# Finished with 127 out of 325 Datapoints
# Finished with 128 out of 325 Datapoints
# Finished with 129 out of 325 Datapoints
# Finished with 130 out of 325 Datapoints
# Finished with 131 out of 325 Datapoints
# Finished with 132 out of 325 Datapoints
# Finished with 133 out of 325 Datapoints
# Finished with 134 out of 325 Datapoints
# Finished with 135 out of 325 Datapoints
# Finished with 136 out of 325 Datapoints
# Finished with 137 out of 325 Datapoints
# Finished with 138 out of 325 Datapoints
# Finished with 139 out of 325 Datapoints
# Finished with 140 out of 325 Datapoints
# Finished with 141 out of 325 Datapoints
# Finished with 142 out of 325 Datapoints
# Finished with 143 out of 325 Datapoints
# Finished with 144 out of 325 Datapoints
# Finished with 145 out of 325 Datapoints
# Finished with 146 out of 325 Datapoints
# Finished with 147 out of 325 Datapoints
# Finished with 148 out of 325 Datapoints
# Finished with 149 out of 325 Datapoints
# Finished with 150 out of 325 Datapoints
# Finished with 151 out of 325 Datapoints
# Finished with 152 out of 325 Datapoints
# Finished with 153 out of 325 Datapoints
# Finished with 154 out of 325 Datapoints
# Finished with 155 out of 325 Datapoints
# Finished with 156 out of 325 Datapoints
# Finished with 157 out of 325 Datapoints
# Finished with 158 out of 325 Datapoints
# Finished with 159 out of 325 Datapoints
# Finished with 160 out of 325 Datapoints
# Finished with 161 out of 325 Datapoints
# Finished with 162 out of 325 Datapoints
# Finished with 163 out of 325 Datapoints
# Finished with 164 out of 325 Datapoints
# Finished with 165 out of 325 Datapoints
# Finished with 166 out of 325 Datapoints
# Finished with 167 out of 325 Datapoints
# Finished with 168 out of 325 Datapoints
# Finished with 169 out of 325 Datapoints
# Finished with 170 out of 325 Datapoints
# Finished with 171 out of 325 Datapoints
# Finished with 172 out of 325 Datapoints
# Finished with 173 out of 325 Datapoints
# Finished with 174 out of 325 Datapoints
# Finished with 175 out of 325 Datapoints
# Finished with 176 out of 325 Datapoints
# Finished with 177 out of 325 Datapoints
# Finished with 178 out of 325 Datapoints
# Finished with 179 out of 325 Datapoints
# Finished with 180 out of 325 Datapoints
# Finished with 181 out of 325 Datapoints
# Finished with 182 out of 325 Datapoints
# Finished with 183 out of 325 Datapoints
# Finished with 184 out of 325 Datapoints
# Finished with 185 out of 325 Datapoints
# Finished with 186 out of 325 Datapoints
# Finished with 187 out of 325 Datapoints
# Finished with 188 out of 325 Datapoints
# Finished with 189 out of 325 Datapoints
# Finished with 190 out of 325 Datapoints
# Finished with 191 out of 325 Datapoints
# Finished with 192 out of 325 Datapoints
# Finished with 193 out of 325 Datapoints
# Finished with 194 out of 325 Datapoints
# Finished with 195 out of 325 Datapoints
# Finished with 196 out of 325 Datapoints
# Finished with 197 out of 325 Datapoints
# Finished with 198 out of 325 Datapoints
# Finished with 199 out of 325 Datapoints
# Finished with 200 out of 325 Datapoints
# Finished with 201 out of 325 Datapoints
# Finished with 202 out of 325 Datapoints
# Finished with 203 out of 325 Datapoints
# Finished with 204 out of 325 Datapoints
# Finished with 205 out of 325 Datapoints
# Finished with 206 out of 325 Datapoints
# Finished with 207 out of 325 Datapoints
# Finished with 208 out of 325 Datapoints
# Finished with 209 out of 325 Datapoints
# Finished with 210 out of 325 Datapoints
# Finished with 211 out of 325 Datapoints
# Finished with 212 out of 325 Datapoints
# Finished with 213 out of 325 Datapoints
# Finished with 214 out of 325 Datapoints
# Finished with 215 out of 325 Datapoints
# Finished with 216 out of 325 Datapoints
# Finished with 217 out of 325 Datapoints
# Finished with 218 out of 325 Datapoints
# Finished with 219 out of 325 Datapoints
# Finished with 220 out of 325 Datapoints
# Finished with 221 out of 325 Datapoints
# Finished with 222 out of 325 Datapoints
# Finished with 223 out of 325 Datapoints
# Finished with 224 out of 325 Datapoints
# Finished with 225 out of 325 Datapoints
# Finished with 226 out of 325 Datapoints
# Finished with 227 out of 325 Datapoints
# Finished with 228 out of 325 Datapoints
# Finished with 229 out of 325 Datapoints
# Finished with 230 out of 325 Datapoints
# Finished with 231 out of 325 Datapoints
# Finished with 232 out of 325 Datapoints
# Finished with 233 out of 325 Datapoints
# Finished with 234 out of 325 Datapoints
# Finished with 235 out of 325 Datapoints
# Finished with 236 out of 325 Datapoints
# Finished with 237 out of 325 Datapoints
# Finished with 238 out of 325 Datapoints
# Finished with 239 out of 325 Datapoints
# Finished with 240 out of 325 Datapoints
# Finished with 241 out of 325 Datapoints
# Finished with 242 out of 325 Datapoints
# Finished with 243 out of 325 Datapoints
# Finished with 244 out of 325 Datapoints
# Finished with 245 out of 325 Datapoints
# Finished with 246 out of 325 Datapoints
# Finished with 247 out of 325 Datapoints
# Finished with 248 out of 325 Datapoints
# Finished with 249 out of 325 Datapoints
# Finished with 250 out of 325 Datapoints
# Finished with 251 out of 325 Datapoints
# Finished with 252 out of 325 Datapoints
# Finished with 253 out of 325 Datapoints
# Finished with 254 out of 325 Datapoints
# Finished with 255 out of 325 Datapoints
# Finished with 256 out of 325 Datapoints
# Finished with 257 out of 325 Datapoints
# Finished with 258 out of 325 Datapoints
# Finished with 259 out of 325 Datapoints
# Finished with 260 out of 325 Datapoints
# Finished with 261 out of 325 Datapoints
# Finished with 262 out of 325 Datapoints
# Finished with 263 out of 325 Datapoints
# Finished with 264 out of 325 Datapoints
# Finished with 265 out of 325 Datapoints
# Finished with 266 out of 325 Datapoints
# Finished with 267 out of 325 Datapoints
# Finished with 268 out of 325 Datapoints
# Finished with 269 out of 325 Datapoints
# Finished with 270 out of 325 Datapoints
# Finished with 271 out of 325 Datapoints
# Finished with 272 out of 325 Datapoints
# Finished with 273 out of 325 Datapoints
# Finished with 274 out of 325 Datapoints
# Finished with 275 out of 325 Datapoints
# Finished with 276 out of 325 Datapoints
# Finished with 277 out of 325 Datapoints
# Finished with 278 out of 325 Datapoints
# Finished with 279 out of 325 Datapoints
# Finished with 280 out of 325 Datapoints
# Finished with 281 out of 325 Datapoints
# Finished with 282 out of 325 Datapoints
# Finished with 283 out of 325 Datapoints
# Finished with 284 out of 325 Datapoints
# Finished with 285 out of 325 Datapoints
# Finished with 286 out of 325 Datapoints
# Finished with 287 out of 325 Datapoints
# Finished with 288 out of 325 Datapoints
# Finished with 289 out of 325 Datapoints
# Finished with 290 out of 325 Datapoints
# Finished with 291 out of 325 Datapoints
# Finished with 292 out of 325 Datapoints
# Finished with 293 out of 325 Datapoints
# Finished with 294 out of 325 Datapoints
# Finished with 295 out of 325 Datapoints
# Finished with 296 out of 325 Datapoints
# Finished with 297 out of 325 Datapoints
# Finished with 298 out of 325 Datapoints
# Finished with 299 out of 325 Datapoints
# Finished with 300 out of 325 Datapoints
# Finished with 301 out of 325 Datapoints
# Finished with 302 out of 325 Datapoints
# Finished with 303 out of 325 Datapoints
# Finished with 304 out of 325 Datapoints
# Finished with 305 out of 325 Datapoints
# Finished with 306 out of 325 Datapoints
# Finished with 307 out of 325 Datapoints
# Finished with 308 out of 325 Datapoints
# Finished with 309 out of 325 Datapoints
# Finished with 310 out of 325 Datapoints
# Finished with 311 out of 325 Datapoints
# Finished with 312 out of 325 Datapoints
# Finished with 313 out of 325 Datapoints
# Finished with 314 out of 325 Datapoints
# Finished with 315 out of 325 Datapoints
# Finished with 316 out of 325 Datapoints
# Finished with 317 out of 325 Datapoints
# Finished with 318 out of 325 Datapoints
# Finished with 319 out of 325 Datapoints
# Finished with 320 out of 325 Datapoints
# Finished with 321 out of 325 Datapoints
# Finished with 322 out of 325 Datapoints
# Finished with 323 out of 325 Datapoints
# Finished with 324 out of 325 Datapoints
# Finished with 325 out of 325 Datapoints

# %%
# Plot Weight Minimising Costs vs. Weight without Rebalancing
Data['WeightA'].plot()
Data['Min_Cost_Weight'].plot()
plt.title('No Rebalancing Weight vs Minimum Cost Weight')
plt.xlabel('Days')
plt.ylabel('Weight')
plt.legend(['No-Rebalancing Weight','Minimum Cost Weight'], loc='upper left')
plt.show()

# Plot Weight with Dynamic Programming Rebalancing
Data['New_WeightA'].plot()
plt.title('PD Rebalancing')
plt.xlabel('Days')
plt.ylabel('Weight of Asset A (Developed Market Index)')
plt.show()

#  Calculate Total Costs of Rebalancing using Dynamic Programming
TC_DM = 0.0
for i in range(1,len(Data)):
    if Data['Rebalance'][i] == 1:
        TC_DM = TC_DM + Data['TC'][i]*1000

print (' ')
print ('Total Costs of Rebalancing using Dynamic Programming ' + str(TC_DM))

# Save output file to current directory
Data.to_csv('Optimal.csv')

# Print Time it Took to Run Code
print ('Total Run Time: ' + str(time.clock() - t0,))
# Out:
#
# Total Costs of Rebalancing using Dynamic Programming 1951949.9999998384
# Total Run Time: 1057.479637

# %%
CData
# Out:
#          Date  Close_A  Close_B  Returns_A  Returns_B   WeightA   InvestmentA  \
# 0    02/01/13    57.74   780.59   0.000000   0.000000  0.614500  6.145000e+08
# 1    03/01/13    57.18   789.90  -0.009699   0.011927  0.609370  6.085402e+08
# 2    04/01/13    57.47   786.10   0.005072  -0.004811  0.611720  7.045391e+08
# 3    07/01/13    57.22   785.75  -0.004350  -0.000445  0.610790  6.576031e+08
# 4    08/01/13    56.90   785.09  -0.005592  -0.000840  0.609656  5.297775e+08
# ..        ...      ...      ...        ...        ...       ...           ...
# 321  11/04/14    66.26   671.49  -0.006001  -0.001324  0.680149  7.917334e+08
# 322  14/04/14    66.64   669.34   0.005735  -0.003202  0.682087  6.174910e+08
# 323  15/04/14    66.36   666.55  -0.004202  -0.004168  0.682080  6.148965e+08
# 324  16/04/14    67.18   665.97   0.012357  -0.000870  0.684925  3.133083e+08
# 325  17/04/14    67.53   664.05   0.005210  -0.002883  0.686667  7.676541e+08
#
#       InvestmentB  Total_Returns  Variance  ...  Variance_Optimal  \
# 0    3.855000e+08       0.000000       0.0  ...      0.000000e+00
# 1    3.900978e+08      -0.001362       0.0  ...      5.085401e-05
# 2    2.940989e+08       0.001211       0.0  ...      9.376937e-06
# 3    3.410349e+08      -0.002834       0.0  ...      7.869595e-08
# 4    4.688605e+08      -0.003743       0.0  ...      9.099240e-07
# ..            ...            ...       ...  ...               ...
# 321  1.884111e+08      -0.004509       0.0  ...      5.246960e-07
# 322  3.626535e+08       0.002877       0.0  ...      6.747576e-06
# 323  3.611418e+08      -0.004191       0.0  ...     -1.828277e-06
# 324  6.627300e+08       0.008152       0.0  ...      1.693729e-05
# 325  2.083842e+08       0.002660       0.0  ...      5.180539e-06
#
#      Expected_Utility_Optimal     TC          CEC  Min_Cost_Weight  \
# 0                    0.000000   0.00     0.000000           0.6145
# 1                   -0.000025   9.10 -1066.449736           0.7055
# 2                   -0.000301   4.40   -61.995691           0.6585
# 3                   -0.000022   8.40   -60.592746           0.5305
# 4                   -0.000325   4.80   -25.926450           0.5665
# ..                        ...    ...          ...              ...
# 321                  0.000064   1.55    -4.027366           0.6300
# 322                  0.000055  13.35  -481.794828           0.7480
# 323                  0.000063  29.35  -327.423580           0.3210
# 324                  0.000048  17.20 -1591.699626           0.7865
# 325                  0.000064  12.65  -369.068125           0.7410
#
#      Total_Costs  Low_Bound  High_Bound  Rebalance  New_WeightA
# 0       0.000000     0.0000      0.0000        0.0     0.614500
# 1       0.000000     0.6140      0.7970        1.0     0.609370
# 2     -57.595691     0.6140      0.7030        1.0     0.705500
# 3     -52.192746     0.4470      0.6140        1.0     0.658500
# 4     -21.126450     0.5195      0.6140        0.0     0.530500
# ..           ...        ...         ...        ...          ...
# 321    -2.477366     0.6140      0.6465        1.0     0.807772
# 322  -468.444828     0.6140      0.8825        0.0     0.630000
# 323  -298.073580     0.0285      0.6140        1.0     0.629992
# 324 -1574.499626     0.6140      0.9590        1.0     0.321000
# 325  -356.418125     0.6140      0.8685        0.0     0.786500
#
# [326 rows x 21 columns]

# %%
Data
# Out:
#          Date  Close_A  Close_B  Returns_A  Returns_B   WeightA   InvestmentA  \
# 0    02/01/13    57.74   780.59   0.000000   0.000000  0.614500  6.145000e+08
# 1    03/01/13    57.18   789.90  -0.009699   0.011927  0.609370  6.085402e+08
# 2    04/01/13    57.47   786.10   0.005072  -0.004811  0.611720  7.045391e+08
# 3    07/01/13    57.22   785.75  -0.004350  -0.000445  0.610790  6.576031e+08
# 4    08/01/13    56.90   785.09  -0.005592  -0.000840  0.609656  5.297775e+08
# ..        ...      ...      ...        ...        ...       ...           ...
# 321  11/04/14    66.26   671.49  -0.006001  -0.001324  0.680149  7.917334e+08
# 322  14/04/14    66.64   669.34   0.005735  -0.003202  0.682087  6.174910e+08
# 323  15/04/14    66.36   666.55  -0.004202  -0.004168  0.682080  6.148965e+08
# 324  16/04/14    67.18   665.97   0.012357  -0.000870  0.684925  3.133083e+08
# 325  17/04/14    67.53   664.05   0.005210  -0.002883  0.686667  7.676541e+08
#
#       InvestmentB  Total_Returns  Variance  ...  Variance_Optimal  \
# 0    3.855000e+08       0.000000       0.0  ...      0.000000e+00
# 1    3.900978e+08      -0.001362       0.0  ...      5.085401e-05
# 2    2.940989e+08       0.001211       0.0  ...      9.376937e-06
# 3    3.410349e+08      -0.002834       0.0  ...      7.869595e-08
# 4    4.688605e+08      -0.003743       0.0  ...      9.099240e-07
# ..            ...            ...       ...  ...               ...
# 321  1.884111e+08      -0.004509       0.0  ...      5.246960e-07
# 322  3.626535e+08       0.002877       0.0  ...      6.747576e-06
# 323  3.611418e+08      -0.004191       0.0  ...     -1.828277e-06
# 324  6.627300e+08       0.008152       0.0  ...      1.693729e-05
# 325  2.083842e+08       0.002660       0.0  ...      5.180539e-06
#
#      Expected_Utility_Optimal     TC          CEC  Min_Cost_Weight  \
# 0                    0.000000   0.00     0.000000           0.6145
# 1                   -0.000025   9.10 -1066.449736           0.7055
# 2                   -0.000301   4.40   -61.995691           0.6585
# 3                   -0.000022   8.40   -60.592746           0.5305
# 4                   -0.000325   4.80   -25.926450           0.5665
# ..                        ...    ...          ...              ...
# 321                  0.000064   1.55    -4.027366           0.6300
# 322                  0.000055  13.35  -481.794828           0.7480
# 323                  0.000063  29.35  -327.423580           0.3210
# 324                  0.000048  17.20 -1591.699626           0.7865
# 325                  0.000064  12.65  -369.068125           0.7410
#
#      Total_Costs  Low_Bound  High_Bound  Rebalance  New_WeightA
# 0       0.000000     0.0000      0.0000        0.0     0.614500
# 1       0.000000     0.6140      0.7970        1.0     0.609370
# 2     -57.595691     0.6140      0.7030        1.0     0.705500
# 3     -52.192746     0.4470      0.6140        1.0     0.658500
# 4     -21.126450     0.5195      0.6140        0.0     0.530500
# ..           ...        ...         ...        ...          ...
# 321    -2.477366     0.6140      0.6465        1.0     0.807772
# 322  -468.444828     0.6140      0.8825        0.0     0.630000
# 323  -298.073580     0.0285      0.6140        1.0     0.629992
# 324 -1574.499626     0.6140      0.9590        1.0     0.321000
# 325  -356.418125     0.6140      0.8685        0.0     0.786500
#
# [326 rows x 21 columns]
